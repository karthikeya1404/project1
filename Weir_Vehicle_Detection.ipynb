# %%
# Mount Google Drive if videos are stored there
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**WEIR VEHICLE DETECTION**
#
# ##Splitting the frames in video

# %%
import cv2
import os
import random
import shutil

# %%
# Set input and output folder paths
input_folder = '/content/drive/MyDrive/WeirVehicleDetection'  # Path to folder with videos
output_folder = '/content/drive/MyDrive/WeirVehicleDetection/output_frames'  # Path to save frames

# Create output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to extract and save 50 random frames from a video
def save_random_frames(video_path, output_folder, frame_count=50):
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f"Error opening video: {video_path}")
        return

    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_indices = random.sample(range(total_frames), min(frame_count, total_frames))
    frame_indices.sort()

    frame_idx = 0
    extracted_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if frame_idx in frame_indices:
            frame_filename = os.path.join(output_folder, f"{video_name}_frame_{frame_idx}.jpg")
            cv2.imwrite(frame_filename, frame)
            extracted_count += 1
            if extracted_count >= frame_count:
                break

        frame_idx += 1

    cap.release()

# Process each video in the input folder
for video_file in os.listdir(input_folder):
    video_path = os.path.join(input_folder, video_file)
    if os.path.isfile(video_path) and video_file.lower().endswith(('.mp4', '.avi', '.mov', '.mkv')):
        print(f"Processing video: {video_file}")
        save_random_frames(video_path, output_folder)

print(f"Frames saved in: {output_folder}")
# Out:
# Processing video: vlc-record-2024-12-30-18h50m45s-rtsp___10.208.41.138_554-.avi
# Processing video: vlc-record-2024-12-30-19h03m25s-rtsp___10.208.41.87_554-.avi
# Processing video: vlc-record-2024-12-30-19h06m34s-rtsp___10.208.41.85_554-.avi
# Processing video: vlc-record-2024-12-30-19h08m25s-rtsp___10.208.41.85_554-.avi
# Frames saved in: /content/drive/MyDrive/WeirVehicleDetection/output_frames

# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv8 Object Detection on a Custom Dataset
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/wuZtUMEiKWY)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# Ultralytics YOLOv8 is a popular version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## Disclaimer
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the accompanying [Blog Post](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset/).
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - CLI Basics
# - Inference with Pre-trained COCO Model
# - Roboflow Universe
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import os

# Construct a path relative to the current working directory
HOME = os.path.join(os.getcwd(), '/content/drive/MyDrive/WeirVehicleDetection/VehicleDetection')
print(HOME)
# Out:
# /content/drive/MyDrive/WeirVehicleDetection/VehicleDetection

# %% [markdown]
# ## Install YOLOv8
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.1/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 78.7MB/s]
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100% 104k/104k [00:00<00:00, 76.9MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 124.5ms
# Speed: 17.1ms preprocess, 124.5ms inference, 2178.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 82.0ms
# Speed: 3.4ms preprocess, 82.0ms inference, 1081.0ms postprocess per image at shape (1, 3, 640, 384)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[   0.0000,  314.4717,  625.0754, 1278.1946],
#         [  55.1731,  250.0220,  648.1080, 1266.2720],
#         [ 633.2291,  719.5391,  701.0538,  786.0336]], device='cuda:0')

# %%
results[0].boxes.conf
# Out:
# tensor([0.7271, 0.2907, 0.2846], device='cuda:0')

# %%
results[0].boxes.cls
# Out:
# tensor([ 0., 16.,  2.], device='cuda:0')

# %% [markdown]
# ## Roboflow Universe
#
# Need data for your project? Before spending time on annotating, check out Roboflow Universe, a repository of more than 110,000 open-source datasets that you can use in your projects. You'll find datasets containing everything from annotated cracks in concrete to plant images with disease annotations.
#
#
# [![Roboflow Universe](https://media.roboflow.com/notebooks/template/uni-banner-frame.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672878480290)](https://universe.roboflow.com/)

# %% [markdown]
# ## Preparing a custom dataset
#
# Building a custom dataset can be a painful process. It might take dozens or even hundreds of hours to collect images, label them, and export them in the proper format. Fortunately, Roboflow makes this process as straightforward and fast as possible. Let me show you how!
#
# ### Step 1: Creating project
#
# Before you start, you need to create a Roboflow [account](https://app.roboflow.com/login). Once you do that, you can create a new project in the Roboflow [dashboard](https://app.roboflow.com/). Keep in mind to choose the right project type. In our case, Object Detection.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/creating-project.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929799852"
#   >
# </div>
#
# ### Step 2: Uploading images
#
# Next, add the data to your newly created project. You can do it via API or through our [web interface](https://docs.roboflow.com/adding-data/object-detection).
#
# If you drag and drop a directory with a dataset in a [supported format](https://roboflow.com/formats), the Roboflow dashboard will automatically read the images and annotations together.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/uploading-images.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929808290"
#   >
# </div>
#
# ### Step 3: Labeling
#
# If you only have images, you can label them in [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# <div align="center">
#   <img
#     width="640"
#     src="https://user-images.githubusercontent.com/26109316/210901980-04861efd-dfc0-4a01-9373-13a36b5e1df4.gif"
#   >
# </div>
#
# ### Step 4: Generate new dataset version
#
# Now that we have our images and annotations added, we can Generate a Dataset Version. When Generating a Version, you may elect to add preprocessing and augmentations. This step is completely optional, however, it can allow you to significantly improve the robustness of your model.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/generate-new-version.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1673003597834"
#   >
# </div>
#
# ### Step 5: Exporting dataset
#
# Once the dataset version is generated, we have a hosted dataset we can load directly into our notebook for easy training. Click `Export` and select the `YOLO v8` dataset format. (Formerly, we used to use `Yolov5`, as the gif shows)
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/export.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672943313709"
#   >
# </div>

# %% [markdown]
# 🟢 Tip: The examples below work even if you use our non-custom model. However, you won't be able to deploy it to Roboflow. To do that, create a custom dataset as described below or fork (copy) one into your workspace from Universe.

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow==1.1.48 --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="mUfSmmHEtVInIGvGkBtn")
project = rf.workspace("pesitm-3e3x4").project("weirvehiclemodel")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# /content/drive/MyDrive/WeirVehicleDetection/VehicleDetection/datasets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.9 MB/s eta 0:00:00
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in WeirVehicleModel-1 to yolov8:: 100%|██████████| 93986/93986 [00:10<00:00, 9000.92it/s]
# Extracting Dataset Version Zip to WeirVehicleModel-1 in yolov8:: 100%|██████████| 1712/1712 [00:20<00:00, 81.63it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

model.train(task='detect', mode='train', data=data_yaml_path, epochs=500, imgsz=530, batch=4)
# Out:
# /content/drive/MyDrive/WeirVehicleDetection/VehicleDetection
# New https://pypi.org/project/ultralytics/8.3.66 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/drive/MyDrive/WeirVehicleDetection/VehicleDetection/datasets/WeirVehicleModel-1/data.yaml, epochs=500, time=None, patience=100, batch=16, imgsz=960, save=True, save_period=10, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 225 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /content/drive/MyDrive/WeirVehicleDetection/VehicleDetection/datasets/WeirVehicleModel-1/train/labels.cache... 594 images, 0 backgrounds, 0 corrupt: 100% 594/594 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 2.0.0 (you have 1.4.20). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/drive/MyDrive/WeirVehicleDetection/VehicleDetection/datasets/WeirVehicleModel-1/valid/labels.cache... 170 images, 0 backgrounds, 0 corrupt: 100% 170/170 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 960 train, 960 val
# Using 0 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 500 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0% 0/38 [00:00<?, ?it/s]^C

# %%
# %cd {HOME}
Image(filename=f'/content/runs/detect/train2/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train2/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train2/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/test-1/valid/labels.cache... 222 images, 20 backgrounds, 0 corrupt: 100% 222/222 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 14/14 [00:06<00:00,  2.04it/s]
#                    all        222        278      0.944      0.901      0.958      0.795
# Speed: 4.2ms preprocess, 14.0ms inference, 0.0ms loss, 4.0ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/109 /content/datasets/test-1/test/images/00056_jpg.rf.8921ff36efb931d2b693c0296b0e3c7d.jpg: 800x800 2 persons, 22.8ms
# image 2/109 /content/datasets/test-1/test/images/00095_jpg.rf.918cacf2bb77bbc0ab806868b3ff8396.jpg: 800x800 2 persons, 22.9ms
# image 3/109 /content/datasets/test-1/test/images/00271_jpg.rf.0a388d4c78840ee8e41b992f3abb0665.jpg: 800x800 3 persons, 22.8ms
# image 4/109 /content/datasets/test-1/test/images/101_JPG_jpg.rf.52c62b5eea4363bb4917e9dd1dc661aa.jpg: 800x800 1 person, 22.8ms
# image 5/109 /content/datasets/test-1/test/images/20220721_162157_jpg.rf.6500e10d05489a67d3a0637377f635a1.jpg: 800x800 (no detections), 22.8ms
# image 6/109 /content/datasets/test-1/test/images/20220721_162157_jpg.rf.6af90fb2cad9a7a90f1290cb645ed5d4.jpg: 800x800 (no detections), 22.8ms
# image 7/109 /content/datasets/test-1/test/images/20220721_162229_jpg.rf.eb1e0356862d791e89f7ab7e5506937e.jpg: 800x800 (no detections), 22.8ms
# image 8/109 /content/datasets/test-1/test/images/AightOne0138_jpg.rf.3da78113aabf114dc8ca20d904e16bd3.jpg: 800x800 2 persons, 22.8ms
# image 9/109 /content/datasets/test-1/test/images/Aitin1788_jpg.rf.f0f58569295ded470feb4d1dca440c42.jpg: 800x800 (no detections), 22.8ms
# image 10/109 /content/datasets/test-1/test/images/Aitin2742_jpg.rf.40e6927d8265006e3975de6a70987fd8.jpg: 800x800 1 person, 22.8ms
# image 11/109 /content/datasets/test-1/test/images/Image_ipg-1958-_jpg.rf.7e133989327e1199860832756f4216d9.jpg: 800x800 1 person, 20.1ms
# image 12/109 /content/datasets/test-1/test/images/KakaoTalk_20221018_001312059_02_jpg.rf.6a39c3d4d31a205a68ab7836ee5296a0.jpg: 800x800 1 person, 14.4ms
# image 13/109 /content/datasets/test-1/test/images/Photin1167_jpg.rf.bdc4cc087106d15d739d0a9c2670103d.jpg: 800x800 (no detections), 14.4ms
# image 14/109 /content/datasets/test-1/test/images/Tan0125_jpg.rf.c980d61d4990489acb881e7df504520a.jpg: 800x800 1 person, 14.4ms
# image 15/109 /content/datasets/test-1/test/images/Tan0150150_jpg.rf.91b648291201a166aadfbabd32a0a33d.jpg: 800x800 1 person, 14.4ms
# image 16/109 /content/datasets/test-1/test/images/Tan0827827_jpg.rf.0f3a239e13aba42f9fb81646c61b0217.jpg: 800x800 (no detections), 14.1ms
# image 17/109 /content/datasets/test-1/test/images/TsirinOne0027_jpg.rf.4a43f7dd2690e21d31402535bc7ead97.jpg: 800x800 6 persons, 14.0ms
# image 18/109 /content/datasets/test-1/test/images/Twalv0611_jpg.rf.fac49eb52488ceecd31ad9f5f59a4ded.jpg: 800x800 (no detections), 14.0ms
# image 19/109 /content/datasets/test-1/test/images/Video1_11_jpg.rf.f5afff50bec23f412b5f065dbe7c0ee6.jpg: 800x800 1 person, 14.0ms
# image 20/109 /content/datasets/test-1/test/images/Video1_16_jpg.rf.d659ff449fd22c91ab71cace5960b6f7.jpg: 800x800 1 person, 12.2ms
# image 21/109 /content/datasets/test-1/test/images/Video1_197_jpg.rf.6aa01ea222d3889faa7273e95bf96cac.jpg: 800x800 1 person, 11.6ms
# image 22/109 /content/datasets/test-1/test/images/Video1_210_jpg.rf.3a74e2ac408e52f612a1cbc1221c7589.jpg: 800x800 1 person, 11.4ms
# image 23/109 /content/datasets/test-1/test/images/Video1_228_jpg.rf.1bfd53fd7d074ecd25c02206a4b2797d.jpg: 800x800 1 person, 11.3ms
# image 24/109 /content/datasets/test-1/test/images/Video1_28_jpg.rf.73e52542e6e00a6929e16cbb5ce46176.jpg: 800x800 1 person, 11.2ms
# image 25/109 /content/datasets/test-1/test/images/Video1_28_jpg.rf.c091b591a5b7eb265c7285157b5400b6.jpg: 800x800 1 person, 11.2ms
# image 26/109 /content/datasets/test-1/test/images/Video1_36_jpg.rf.6569b71430226c3538964957f101919b.jpg: 800x800 1 person, 11.1ms
# image 27/109 /content/datasets/test-1/test/images/Video1_38_jpg.rf.60722adf78546268e3fd595e8ebbe6fb.jpg: 800x800 1 person, 11.2ms
# image 28/109 /content/datasets/test-1/test/images/Video1_47_jpg.rf.192298367fab23712ef873a7cdeee289.jpg: 800x800 1 person, 11.1ms
# image 29/109 /content/datasets/test-1/test/images/Video1_55_jpg.rf.c8893d96f6ef518452e941aec6269caf.jpg: 800x800 1 person, 11.1ms
# image 30/109 /content/datasets/test-1/test/images/Video2_10_jpg.rf.e26df6caf37d6fa69b8d5a9890c07a4e.jpg: 800x800 1 person, 11.1ms
# image 31/109 /content/datasets/test-1/test/images/Video2_140_jpg.rf.e34fd800836a06242f052eaf15d2f88e.jpg: 800x800 1 person, 11.1ms
# image 32/109 /content/datasets/test-1/test/images/Video2_180_jpg.rf.ba204229dbbe2767f91b526dbd22e9b1.jpg: 800x800 1 person, 11.1ms
# image 33/109 /content/datasets/test-1/test/images/Video2_185_jpg.rf.0e16209c40e142a0dbc753dc561d7cad.jpg: 800x800 1 person, 11.1ms
# image 34/109 /content/datasets/test-1/test/images/Video2_21_jpg.rf.67cf4c0851daf60c1d5f93c3ba58ffb5.jpg: 800x800 1 person, 11.0ms
# image 35/109 /content/datasets/test-1/test/images/Video2_38_jpg.rf.ee9a9c6f4feb5d4e44463290f96122ce.jpg: 800x800 1 person, 11.1ms
# image 36/109 /content/datasets/test-1/test/images/Video2_39_jpg.rf.44cd7ddf107023064937c2719bb962d9.jpg: 800x800 1 person, 11.1ms
# image 37/109 /content/datasets/test-1/test/images/Video2_43_jpg.rf.7f477085ccc7b01b071a3e992aa09d1b.jpg: 800x800 1 person, 11.2ms
# image 38/109 /content/datasets/test-1/test/images/Video2_83_jpg.rf.4dc18a832bc1825dac1301f2d73fdb76.jpg: 800x800 1 person, 11.8ms
# image 39/109 /content/datasets/test-1/test/images/Video2_9_jpg.rf.0993d2aa08b76ae81253b603b44807c6.jpg: 800x800 1 person, 12.1ms
# image 40/109 /content/datasets/test-1/test/images/Video3_138_jpg.rf.4470050d3e53736afd13b33809810e7e.jpg: 800x800 1 person, 12.3ms
# image 41/109 /content/datasets/test-1/test/images/Video3_13_jpg.rf.e003acf436ee20d39cac4c6e77eaa643.jpg: 800x800 1 person, 12.3ms
# image 42/109 /content/datasets/test-1/test/images/Video3_147_jpg.rf.fc311753b3832f0c7feb0b70d8eee3f4.jpg: 800x800 1 person, 12.2ms
# image 43/109 /content/datasets/test-1/test/images/Video3_161_jpg.rf.4dfb14798dcf6de540f036b8c173a332.jpg: 800x800 1 person, 11.9ms
# image 44/109 /content/datasets/test-1/test/images/Video3_20_jpg.rf.876e692f0a37f8d893ca61fb51247b46.jpg: 800x800 1 person, 11.7ms
# image 45/109 /content/datasets/test-1/test/images/Video3_231_jpg.rf.dbdb59ddbc6e93f1802b353ecc9c52e1.jpg: 800x800 1 person, 11.4ms
# image 46/109 /content/datasets/test-1/test/images/Video3_23_jpg.rf.a47a5672ac1f165ae30a054a60297e0d.jpg: 800x800 1 person, 11.3ms
# image 47/109 /content/datasets/test-1/test/images/Video3_270_jpg.rf.e14db4cebbab3c9ac2f2c8e26a251302.jpg: 800x800 1 person, 11.2ms
# image 48/109 /content/datasets/test-1/test/images/Video3_279_jpg.rf.a1dfb1b4e607e6d6f265267cce94e55f.jpg: 800x800 1 person, 11.1ms
# image 49/109 /content/datasets/test-1/test/images/Video3_39_jpg.rf.79bb830a28ff476f60513136494e97cf.jpg: 800x800 1 person, 11.1ms
# image 50/109 /content/datasets/test-1/test/images/Video3_42_jpg.rf.3148f2de8f7aff3c40c15c51aa052458.jpg: 800x800 1 person, 11.2ms
# image 51/109 /content/datasets/test-1/test/images/Video3_45_jpg.rf.ccc6dbd7a3f5de65effde89e9e7e4d5e.jpg: 800x800 1 person, 11.1ms
# image 52/109 /content/datasets/test-1/test/images/Video4_13_jpg.rf.e42fe98b3d593d30dad8094b20c151f9.jpg: 800x800 1 person, 11.1ms
# image 53/109 /content/datasets/test-1/test/images/Video4_235_jpg.rf.b00ce1e5e347b8850a23685c6dc1d4b8.jpg: 800x800 1 person, 11.1ms
# image 54/109 /content/datasets/test-1/test/images/Video4_248_jpg.rf.efe8c26f0fdb516d8868ceda076188e6.jpg: 800x800 1 person, 11.1ms
# image 55/109 /content/datasets/test-1/test/images/Video4_254_jpg.rf.3924a79ffc71193c233be12d4a686e88.jpg: 800x800 1 person, 11.1ms
# image 56/109 /content/datasets/test-1/test/images/Video4_270_jpg.rf.6d9c008bde60b05a04a95c83232ab634.jpg: 800x800 1 person, 11.3ms
# image 57/109 /content/datasets/test-1/test/images/Video4_280_jpg.rf.d677b8236776c2c842d66904eeacc6f1.jpg: 800x800 1 person, 11.5ms
# image 58/109 /content/datasets/test-1/test/images/Video4_30_jpg.rf.d28c30f1ad2da7e07d67d46e6929e326.jpg: 800x800 1 person, 11.7ms
# image 59/109 /content/datasets/test-1/test/images/Video4_34_jpg.rf.1aa2b04479eab0921faf15543495972b.jpg: 800x800 1 person, 12.0ms
# image 60/109 /content/datasets/test-1/test/images/Video4_35_jpg.rf.b4c72dd86ef3b72ff815f6e7de2a602c.jpg: 800x800 1 person, 12.3ms
# image 61/109 /content/datasets/test-1/test/images/Video4_36_jpg.rf.73b6dec18bc64870cde2588d67f4b0f3.jpg: 800x800 1 person, 12.4ms
# image 62/109 /content/datasets/test-1/test/images/Video4_48_jpg.rf.b3f957f48e947574f48deec414288e84.jpg: 800x800 1 person, 12.2ms
# image 63/109 /content/datasets/test-1/test/images/Video4_51_jpg.rf.a0df899d3d9b6d081e6b3d2c179c1560.jpg: 800x800 1 person, 12.0ms
# image 64/109 /content/datasets/test-1/test/images/Video4_65_jpg.rf.7af06126a3a3028ce067782f87fb69bf.jpg: 800x800 1 person, 11.4ms
# image 65/109 /content/datasets/test-1/test/images/Video4_82_jpg.rf.217a84475057aae824e5e0600682cdcc.jpg: 800x800 1 person, 11.3ms
# image 66/109 /content/datasets/test-1/test/images/construction-crack-146741_jpg.rf.cacfd5296e83d8e03e1a2d82449dca4e.jpg: 800x800 1 person, 11.2ms
# image 67/109 /content/datasets/test-1/test/images/download-3-_jpeg_jpg.rf.1d791da192b8453e707d5f2cc248542e.jpg: 800x800 1 person, 11.3ms
# image 68/109 /content/datasets/test-1/test/images/frame_0001_jpg.rf.6d59039359e31202b08e9a01135fb058.jpg: 800x800 1 person, 11.5ms
# image 69/109 /content/datasets/test-1/test/images/frame_0008_jpg.rf.480ac6b15aca45dc3f5326a2e5947469.jpg: 800x800 1 person, 11.9ms
# image 70/109 /content/datasets/test-1/test/images/frame_0011_jpg.rf.b0aa05b02de4c25f73723cfeb9405f4c.jpg: 800x800 1 person, 12.2ms
# image 71/109 /content/datasets/test-1/test/images/frame_0023_jpg.rf.1f2f6933207b9c3c043dd2fcabdff697.jpg: 800x800 1 person, 12.1ms
# image 72/109 /content/datasets/test-1/test/images/image_153_jpg.rf.45750d16fea435b53776fe8924b8fa01.jpg: 800x800 1 person, 11.8ms
# image 73/109 /content/datasets/test-1/test/images/image_157_jpg.rf.13ee10f515bd4fce4e6c210ae6013cce.jpg: 800x800 1 person, 11.3ms
# image 74/109 /content/datasets/test-1/test/images/image_162_jpg.rf.7fb899a9b257d33961a237b05daace39.jpg: 800x800 1 person, 11.2ms
# image 75/109 /content/datasets/test-1/test/images/image_166_jpg.rf.6315d369f82153065d6a0fb6cde20f77.jpg: 800x800 1 person, 11.1ms
# image 76/109 /content/datasets/test-1/test/images/image_167_jpg.rf.13874f5bd027b0268f62b7a02b2c9c7d.jpg: 800x800 1 person, 11.1ms
# image 77/109 /content/datasets/test-1/test/images/image_181_jpg.rf.9973edca64c3331b416508d06398713f.jpg: 800x800 1 person, 11.2ms
# image 78/109 /content/datasets/test-1/test/images/image_186_jpg.rf.eced7bcda9fc05946a1c6ca78da25047.jpg: 800x800 2 persons, 11.5ms
# image 79/109 /content/datasets/test-1/test/images/image_188_jpg.rf.5067fc5a07d73508c7eaa3a5330e8cb6.jpg: 800x800 1 person, 12.1ms
# image 80/109 /content/datasets/test-1/test/images/image_190_jpg.rf.59b1a68e46d35cc3530610f541d4f501.jpg: 800x800 1 person, 12.2ms
# image 81/109 /content/datasets/test-1/test/images/image_193_jpg.rf.5c50c3b9fe15b7c3a6f195457960d897.jpg: 800x800 1 person, 12.0ms
# image 82/109 /content/datasets/test-1/test/images/image_193_jpg.rf.ad73599d0468f93b181df94bd8a19ca0.jpg: 800x800 1 person, 11.7ms
# image 83/109 /content/datasets/test-1/test/images/image_195_jpg.rf.3cd452a12c0f046b9ef0bced8e8a0fae.jpg: 800x800 2 persons, 11.4ms
# image 84/109 /content/datasets/test-1/test/images/image_199_jpg.rf.af35e4c95fe463cefde991537e0a3519.jpg: 800x800 1 person, 11.2ms
# image 85/109 /content/datasets/test-1/test/images/image_199_jpg.rf.fb35bde89c923a81eab0efdd10f260f4.jpg: 800x800 1 person, 11.2ms
# image 86/109 /content/datasets/test-1/test/images/image_213_jpg.rf.45ec3d986ee840b90dd835672162633a.jpg: 800x800 1 person, 11.2ms
# image 87/109 /content/datasets/test-1/test/images/image_214_jpg.rf.7086697c335d48f9f926d409fab48a0d.jpg: 800x800 1 person, 11.1ms
# image 88/109 /content/datasets/test-1/test/images/image_215_jpg.rf.06fce0e8f8a9bc5216addaa9c98d2af7.jpg: 800x800 1 person, 11.1ms
# image 89/109 /content/datasets/test-1/test/images/image_215_jpg.rf.91e2ac20e11ab58f9407752c5ff08415.jpg: 800x800 1 person, 11.2ms
# image 90/109 /content/datasets/test-1/test/images/image_233_jpg.rf.33c510a84dba432ec5200d479ee9e278.jpg: 800x800 1 person, 11.2ms
# image 91/109 /content/datasets/test-1/test/images/image_234_jpg.rf.04ac68705c8f3f0d3a83aa3920ebfeba.jpg: 800x800 1 person, 11.3ms
# image 92/109 /content/datasets/test-1/test/images/image_236_jpg.rf.17c1a1e289bc55401f95b3ac5133f800.jpg: 800x800 1 person, 11.5ms
# image 93/109 /content/datasets/test-1/test/images/image_242-1-_jpg.rf.07413f47919aa7bfd8b06551ce5619b7.jpg: 800x800 1 person, 11.9ms
# image 94/109 /content/datasets/test-1/test/images/image_260_jpg.rf.5b54ca34dee6ca46e913a34436df9d02.jpg: 800x800 1 person, 12.4ms
# image 95/109 /content/datasets/test-1/test/images/image_264_jpg.rf.30c6c43d993966f0c411c4f125497c8b.jpg: 800x800 1 person, 12.4ms
# image 96/109 /content/datasets/test-1/test/images/image_317_jpg.rf.963e41ee3e7eb882da974fa9fee5daa8.jpg: 800x800 1 person, 12.2ms
# image 97/109 /content/datasets/test-1/test/images/image_62_jpg.rf.89f49a7612ec08b859d32bacc6154cfd.jpg: 800x800 1 person, 11.9ms
# image 98/109 /content/datasets/test-1/test/images/image_62_jpg.rf.edf914b85c336c48957ad27243b14562.jpg: 800x800 1 person, 11.6ms
# image 99/109 /content/datasets/test-1/test/images/images-2022-07-04T012941-1-_jpg.rf.363ba3021a07bf93d212784655cb6450.jpg: 800x800 1 person, 11.3ms
# image 100/109 /content/datasets/test-1/test/images/images-2022-07-04T013435_jpg.rf.7cd9b518807e065931123e8021efa88d.jpg: 800x800 1 person, 11.2ms
# image 101/109 /content/datasets/test-1/test/images/ppe_0153_jpg.rf.8c749da8c48ccbc324be4dfc4b8b5503.jpg: 800x800 2 persons, 11.2ms
# image 102/109 /content/datasets/test-1/test/images/ppe_0307_jpg.rf.b1cfc273cab4d98687d88a4aec45bc0d.jpg: 800x800 1 person, 11.2ms
# image 103/109 /content/datasets/test-1/test/images/ppe_0374_jpg.rf.4c21d0c0eaa75b75ecc406af21d6f3ec.jpg: 800x800 6 persons, 11.3ms
# image 104/109 /content/datasets/test-1/test/images/ppe_0546_jpg.rf.dc6a041ef13bfb927ca9b1e95fd6bd97.jpg: 800x800 1 person, 11.4ms
# image 105/109 /content/datasets/test-1/test/images/ppe_0873_jpg.rf.02c0581082bf96bee3fbfd06cff8fcfd.jpg: 800x800 4 persons, 12.0ms
# image 106/109 /content/datasets/test-1/test/images/r107_jpg.rf.6a7d7a9bd7320b9875b1675cadd0003a.jpg: 800x800 6 persons, 12.0ms
# image 107/109 /content/datasets/test-1/test/images/r113_jpg.rf.4a7be6111524ec355661fb1dad7e5480.jpg: 800x800 2 persons, 11.9ms
# image 108/109 /content/datasets/test-1/test/images/r168_jpg.rf.d5ccf53355414ed8244c3ab81ce28187.jpg: 800x800 1 person, 11.7ms
# image 109/109 /content/datasets/test-1/test/images/sic5242_jpg.rf.4a539b0db9df79ec147b37aad7b520ce.jpg: 800x800 1 person, 11.4ms
# Speed: 3.9ms preprocess, 12.8ms inference, 6.2ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")

# %% [markdown]
# ##Test that on the video

# %%
import cv2
import os
from ultralytics import YOLO  # Import YOLO from ultralytics

# Paths for the input and output folders, and the YOLO model
input_folder = '/content/drive/MyDrive/WeirVehicleDetection/TestOutput/TestVideos'  # Path to the folder containing input videos
output_folder = '/content/drive/MyDrive/WeirVehicleDetection/TestOutput/TestOutput2'  # Path to save processed videos
model_path = '/content/drive/MyDrive/WeirVehicleDetection/Models/v8_s.pt'  # Path to the YOLO model file

# Ensure the output folder exists
os.makedirs(output_folder, exist_ok=True)

# Load the YOLO model
model = YOLO('/content/drive/MyDrive/WeirVehicleDetection/Models/v8_s.pt')

# Process all videos in the input folder
for video_file in os.listdir(input_folder):
    # Full path to the input video
    input_video = os.path.join(input_folder, video_file)

    # Check if the file is a video (based on file extension)
    if not input_video.lower().endswith(('.mp4', '.avi', '.mkv', '.mov')):
        continue

    # Full path for the output video
    output_video = os.path.join(output_folder, f"processed_{video_file}")

    # Open the video file
    cap = cv2.VideoCapture(input_video)
    if not cap.isOpened():
        print(f"Error opening video: {input_video}")
        continue

    # Get video properties
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Define the codec and create VideoWriter object
    out = cv2.VideoWriter(output_video, cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Run YOLO inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()  # Annotated frame with detections

        # Write the annotated frame to the output video
        out.write(annotated_frame)

    # Release resources for the current video
    cap.release()
    out.release()
    print(f"Processed video saved at: {output_video}")

print("All videos processed and saved.")
# Out:
# WARNING ⚠️ /content/drive/MyDrive/WeirVehicleDetection/Models/v8_s.pt appears to require 'nets', which is not in Ultralytics requirements.
# AutoInstall will run now for 'nets' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official Ultralytics model, i.e. 'yolo predict model=yolov8n.pt'
# requirements: Ultralytics requirement ['nets'] not found, attempting AutoUpdate...
# Collecting nets
#   Downloading nets-0.0.3.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from nets) (1.26.4)
# Downloading nets-0.0.3.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: nets
# Successfully installed nets-0.0.3.1
#
# requirements: AutoUpdate success ✅ 3.1s, installed 1 package: ['nets']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in torch_safe_load(weight, safe_only)
#     832             else:
# --> 833                 ckpt = torch.load(file, map_location="cpu")
#     834
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/patches.py in torch_load(*args, **kwargs)
#      85
# ---> 86     return _torch_load(*args, **kwargs)
#      87
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1359                         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1360                 return _load(
#    1361                     opened_zipfile,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1847     _serialization_tls.map_location = map_location
# -> 1848     result = unpickler.load()
#    1849     _serialization_tls.map_location = None
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in find_class(self, mod_name, name)
#    1836             mod_name = load_module_mapping.get(mod_name, mod_name)
# -> 1837             return super().find_class(mod_name, name)
#    1838
#
# ModuleNotFoundError: No module named 'nets'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/cupy/__init__.py in <module>
#      16 try:
# ---> 17     from cupy import _core  # NOQA
#      18 except ImportError as exc:
#
# /usr/local/lib/python3.11/dist-packages/cupy/_core/__init__.py in <module>
#       2
# ----> 3 from cupy._core import core  # NOQA
#       4 from cupy._core import fusion  # NOQA
#
# ImportError: libcuda.so.1: cannot open shared object file: No such file or directory
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-7e4c4ffa424f> in <cell line: 0>()
#      12
#      13 # Load the YOLO model
# ---> 14 model = YOLO('/content/drive/MyDrive/WeirVehicleDetection/Models/v8_s.pt')
#      15
#      16 # Process all videos in the input folder
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      21         else:
#      22             # Continue with default YOLO initialization
# ---> 23             super().__init__(model=model, task=task, verbose=verbose)
#      24
#      25     @property
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
#     143             self._new(model, task=task, verbose=verbose)
#     144         else:
# --> 145             self._load(model, task=task)
#     146
#     147     def __call__(
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in _load(self, weights, task)
#     283
#     284         if Path(weights).suffix == ".pt":
# --> 285             self.model, self.ckpt = attempt_load_one_weight(weights)
#     286             self.task = self.model.args["task"]
#     287             self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in attempt_load_one_weight(weight, device, inplace, fuse)
#     904 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#     905     """Loads a single model weights."""
# --> 906     ckpt, weight = torch_safe_load(weight)  # load ckpt
#     907     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#     908     model = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in torch_safe_load(weight, safe_only)
#     851         )
#     852         check_requirements(e.name)  # install missing module
# --> 853         ckpt = torch.load(file, map_location="cpu")
#     854
#     855     if not isinstance(ckpt, dict):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/patches.py in torch_load(*args, **kwargs)
#      84         kwargs["weights_only"] = False
#      85
# ---> 86     return _torch_load(*args, **kwargs)
#      87
#      88
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1358                     except pickle.UnpicklingError as e:
#    1359                         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1360                 return _load(
#    1361                     opened_zipfile,
#    1362                     map_location,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1846     global _serialization_tls
#    1847     _serialization_tls.map_location = map_location
# -> 1848     result = unpickler.load()
#    1849     _serialization_tls.map_location = None
#    1850
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in find_class(self, mod_name, name)
#    1835                     pass
#    1836             mod_name = load_module_mapping.get(mod_name, mod_name)
# -> 1837             return super().find_class(mod_name, name)
#    1838
#    1839     # Load the data (which may in turn use `persistent_load` to load tensors)
#
# /usr/local/lib/python3.11/dist-packages/nets/__init__.py in <module>
#       1 # Main package
# ----> 2 from nets.tensor import Tensor, to_numpy, to_cupy, to_tensor, tensor2string
#       3 from nets.numeric import *
#       4
#       5 from nets.autograd import Hook, Parameter
#
# /usr/local/lib/python3.11/dist-packages/nets/tensor.py in <module>
#      15 import numpy as np
#      16 try:
# ---> 17     import cupy as cp
#      18 except ModuleNotFoundError:
#      19     pass
#
# /usr/local/lib/python3.11/dist-packages/cupy/__init__.py in <module>
#      17     from cupy import _core  # NOQA
#      18 except ImportError as exc:
# ---> 19     raise ImportError(f'''
#      20 ================================================================
#      21 {_environment._diagnose_import_error()}
#
# ImportError:
# ================================================================
# Failed to import CuPy.
#
# If you installed CuPy via wheels (cupy-cudaXXX or cupy-rocm-X-X), make sure that the package matches with the version of CUDA or ROCm installed.
#
# On Linux, you may need to set LD_LIBRARY_PATH environment variable depending on how you installed CUDA/ROCm.
# On Windows, try setting CUDA_PATH environment variable.
#
# Check the Installation Guide for details:
#   https://docs.cupy.dev/en/latest/install.html
#
# Original error:
#   ImportError: libcuda.so.1: cannot open shared object file: No such file or directory
# ================================================================
#
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.2.103, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/model-examples/football-players-obj-detection/2
# Share your model with the world at: https://universe.roboflow.com/model-examples/football-players-obj-detection/model/2

# %% [markdown]
# Follow the links above to check if the upload succeeded. It may take a couple of minutes until the model is visible to the `roboflow` SDK.

# %%
# Run inference on your model on a persistent, auto-scaling, cloud API

# Load model
model = project.version(dataset.version).model
assert model, "Model deployment is still loading"

# Choose a random test image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# running inference on 4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg
# {'predictions': [{'x': 1227.0,
#    'y': 527.5,
#    'width': 50.0,
#    'height': 77.0,
#    'confidence': 0.9045102000236511,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '7bb0de78-c58d-454a-b693-c3f518f94f80',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 731.0,
#    'y': 584.5,
#    'width': 52.0,
#    'height': 79.0,
#    'confidence': 0.8924632668495178,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'b3ea8a5a-5294-45c9-9221-ba8a6f0884b5',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1397.5,
#    'y': 344.5,
#    'width': 31.0,
#    'height': 55.0,
#    'confidence': 0.8912790417671204,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '5ef87756-163e-442c-ad88-35f3572750d5',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1447.0,
#    'y': 476.5,
#    'width': 32.0,
#    'height': 73.0,
#    'confidence': 0.8694518804550171,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '89a9e4d7-0b7b-4cc0-8596-cf90522a5f86',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1271.0,
#    'y': 583.0,
#    'width': 36.0,
#    'height': 82.0,
#    'confidence': 0.8614903688430786,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '74b59e7e-03a8-477c-bb65-872b55cee6d2',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 332.5,
#    'y': 474.0,
#    'width': 33.0,
#    'height': 72.0,
#    'confidence': 0.8610998392105103,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '50984141-2378-4a7d-8b40-9e353bcf50d9',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 513.5,
#    'y': 379.5,
#    'width': 43.0,
#    'height': 57.0,
#    'confidence': 0.8593119978904724,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '131a232d-1403-498c-8714-ee9bc72768f1',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1050.5,
#    'y': 404.0,
#    'width': 25.0,
#    'height': 66.0,
#    'confidence': 0.8461295962333679,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '17c1060d-60c1-4684-8190-99f32976e3b6',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1524.0,
#    'y': 468.5,
#    'width': 28.0,
#    'height': 75.0,
#    'confidence': 0.8449162244796753,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'b78f434e-4fe3-4d7f-969c-2b540118a036',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 862.0,
#    'y': 299.0,
#    'width': 18.0,
#    'height': 46.0,
#    'confidence': 0.8436365723609924,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'a04d6b50-dfae-4bd3-934a-7c535ae86a6d',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 286.0,
#    'y': 409.0,
#    'width': 28.0,
#    'height': 66.0,
#    'confidence': 0.8423029780387878,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'd4868dd9-213d-4242-b5f4-b0a28bfa5c51',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1113.0,
#    'y': 398.5,
#    'width': 22.0,
#    'height': 65.0,
#    'confidence': 0.8421118855476379,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '808cbedf-7404-41a5-ac38-61a46bfab755',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 867.5,
#    'y': 447.0,
#    'width': 25.0,
#    'height': 70.0,
#    'confidence': 0.8394479155540466,
#    'class': 'referee',
#    'class_id': 3,
#    'detection_id': '3e0537d1-ca58-438c-9323-702e21ddacd2',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 803.0,
#    'y': 461.5,
#    'width': 26.0,
#    'height': 69.0,
#    'confidence': 0.8217413425445557,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'bbdcdcff-9007-4311-96e3-e8a5079f177e',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 832.5,
#    'y': 475.5,
#    'width': 29.0,
#    'height': 67.0,
#    'confidence': 0.8183465003967285,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '9ff9c162-4288-42c4-a90c-c67983551391',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 593.5,
#    'y': 386.5,
#    'width': 25.0,
#    'height': 57.0,
#    'confidence': 0.7829996943473816,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '0898f653-a519-4c0d-abf4-c2f07c38be51',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 647.0,
#    'y': 421.0,
#    'width': 36.0,
#    'height': 64.0,
#    'confidence': 0.771634578704834,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '599da973-e6b5-4d13-b990-480f7a58b083',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 737.0,
#    'y': 239.5,
#    'width': 24.0,
#    'height': 35.0,
#    'confidence': 0.7465640902519226,
#    'class': 'referee',
#    'class_id': 3,
#    'detection_id': 'ba786450-37a1-46bf-a80a-b28eb7252058',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1552.5,
#    'y': 404.5,
#    'width': 27.0,
#    'height': 67.0,
#    'confidence': 0.6716049909591675,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'fd36f2e9-6911-4d9e-93cd-3bd5b75263d0',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'}],
#  'image': {'width': '1920', 'height': '1080'}}

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_thresh,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
